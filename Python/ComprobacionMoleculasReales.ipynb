# %%
import sys
sys.path.append('./Files')
import os
import matplotlib.pyplot as plt
import time
import macroC as mC 
import numpy as np
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.hamiltonians import QuadraticHamiltonian
from qiskit.quantum_info import Operator

# %%
def getSpectrum(shifts,J,d,SW,B,offset):
    # Construimos el SpinSystem asociado, añadiendo los shifts primero y los acoplamientos J después.
    sscase = mC.SpinSystem()
    n=len(shifts)
    for i in range(n):
        sscase.addNuc(str(i), shifts[i])
    k=0
    for i in range(n):
        for j in range(i+1,n):
            sscase.addJ(str(i), str(j), J[k])
            k+=1
    sscase.level=1
    
    # Construimos el simulador NMR
    nmrsim = mC.NMRSimulator()
    nmrsim.setField(B)
    nmrsim.setTD(d) # Resolución del espectro
    nmrsim.setSWPPM(SW) # Ancho espectral
    nmrsim.setOffsetPPM(offset)
    nmrsim.setT2(2.0)
    sss = []
    sss.append(sscase)
    # Calculamos el espectro teórico
    spcOutteo, fsteo, v, w= nmrsim.simSpectrum(sss)
    return spcOutteo, fsteo

# %%
H, shifts, Jlist, B, offset=mC.bromoethane()
SW=10
d=10**4

# %%
spcOutteo, fsteo=getSpectrum(shifts,Jlist,d,SW,B,offset)

# %%
plt.plot(fsteo, spcOutteo,'-', label='Theoretical Spectrum', color='red',lw=2)
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(fsteo, spcOutteo,'-', label='Theoretical Spectrum', color='red',lw=2)
plt.legend()
plt.grid()
plt.xlim(3.46,3.4)
plt.show()

# %%
plt.plot(fsteo, spcOutteo,'-', label='Theoretical Spectrum', color='red',lw=2)
plt.legend()
plt.grid()
plt.xlim(1.705,1.664)
plt.show()

# %%
H, shifts, Jlist, B, offset=mC.dichloropropane()
SW=10
d=10**5

# %%
spcOutteo, fsteo=getSpectrum(shifts,Jlist,d,SW,B,offset)

# %%
plt.plot(fsteo, spcOutteo,'-', label='Theoretical Spectrum', color='red',lw=2)
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(fsteo, spcOutteo,'-', label='Theoretical Spectrum', color='red',lw=2)
plt.legend()
plt.grid()
plt.xlim(1.64,1.6)
plt.show()

# %%
plt.plot(fsteo, spcOutteo,'-', label='Theoretical Spectrum', color='red',lw=2)
plt.legend()
plt.grid()
plt.xlim(4.19,4.14)
plt.show()

# %%
plt.plot(fsteo, spcOutteo,'-', label='Theoretical Spectrum', color='red',lw=2)
plt.legend()
plt.grid()
plt.xlim(3.84,3.8)
plt.show()

# %%
plt.plot(fsteo, spcOutteo,'-', label='Theoretical Spectrum', color='red',lw=2)
plt.legend()
plt.grid()
plt.xlim(3.6,3.55)
plt.show()
